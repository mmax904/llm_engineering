# %% [markdown]
# # Animal Mixer

# %% [markdown]
# Given two animal species, let's make a cross between them and visualize the resulting new animal.

# %% [markdown]
# ## Imports

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr
import base64
from io import BytesIO
from PIL import Image
from IPython.display import Audio, display

# %% [markdown]
# ## Initialization

# %%
load_dotenv(override=True)

openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
MODEL = "gpt-4o-mini"
openai = OpenAI()
# Out:
# OpenAI API Key exists and begins sk-MyJrO

# %% [markdown]
# ## System Messages

# %%
system_message = "You are a famous zoologist-surgeon who makes crosses between animals, so new hybrid animals with mixed features of both original animals. "
system_message += "Given two animal species, you create a new species which is a hybrid between the two. Make sure it only has one head. "
system_message += "Describe the new species following the pattern: species X is a hybrid between species A and species B. "
system_message += "Species A and B are the two given species. Describe the new species briefly, in up to 3 sentences. "
system_message += "Always be accurate. If you don't know the answer, say so."

# %% [markdown]
# ## Tools

# %%
def get_animal_name(animal1, animal2):
    print(f"Tool get_animal_name called for the cross between {animal1} and {animal2}")
    first = len(animal1) // 2
    second = len(animal2) // 2
    name = animal1[:first] + animal2[second:]
    return name

# %%
get_animal_name('capybara', 'elephant')
# Out:
# Tool get_animal_name called for the cross between capybara and elephant
# 'capyhant'

# %%
animal_function = {
    "name": "get_animal_name",
    "description": "Get the name of the cross between the two given animals. Call this whenever you are given the names of the two original animals, for example when a user enters 'capybara' and 'elephant'",
    "parameters": {
        "type": "object",
        "properties": {
            "animal1": {
                "type": "string",
                "description": "the first original animal species",
            },
            "animal2": {
                "type": "string",
                "description": "the second original animal species",
            },
        },
        "required": ["animal1", "animal2"],
        "additionalProperties": False
    }
}

# %%
tools = [{"type": "function", "function": animal_function}]

# %% [markdown]
# ## Image

# %%
def artist(animal1, animal2):
    image_response = openai.images.generate(
            model="dall-e-3",
            prompt=f"An image representing a hybrid between {animal1} and {animal2}, with some features of {animal1} and some features of {animal2}, blended smoothly into a single hybrid animal, in photorealistic style. Make sure it only has one head and there is no text in the image.",
            size="1024x1024",
            n=1,
            # response_format="b64_json",
        )
    image_base64 = image_response.data[0].b64_json
    image_data = base64.b64decode(image_base64)
    return Image.open(BytesIO(image_data))

# %%
image = artist("capybara", "elephant")
display(image)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 image = artist("capybara", "elephant")
#       2 display(image)
#
# Cell In[10], line 2, in artist(animal1, animal2)
#       1 def artist(animal1, animal2):
# ----> 2     image_response = openai.images.generate(
#       3             model="dall-e-3",
#       4             prompt=f"An image representing a hybrid between {animal1} and {animal2}, with some features of {animal1} and some features of {animal2}, blended smoothly into a single hybrid animal, in photorealistic style. Make sure it only has one head and there is no text in the image.",
#       5             size="1024x1024",
#
# File ~/Sites/ai-learning/llm_engineering/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~/Sites/ai-learning/llm_engineering/.venv/lib/python3.13/site-packages/openai/resources/images.py:997, in Images.generate(self, prompt, background, model, moderation, n, output_compression, output_format, partial_images, quality, response_format, size, stream, style, user, extra_headers, extra_query, extra_body, timeout)
#     967 @required_args(["prompt"], ["prompt", "stream"])
#     968 def generate(
#     969     self,
#    (...)    995     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     996 ) -> ImagesResponse | Stream[ImageGenStreamEvent]:
# --> 997     return self._post(
#     998         "/images/generations",
#     999         body=maybe_transform(
#    1000             {
#    1001                 "prompt": prompt,
#    1002                 "background": background,
#    1003                 "model": model,
#    1004                 "moderation": moderation,
#    1005                 "n": n,
#    1006                 "output_compression": output_compression,
#    1007                 "output_format": output_format,
#    1008                 "partial_images": partial_images,
#    1009                 "quality": quality,
#    1010                 "response_format": response_format,
#    1011                 "size": size,
#    1012                 "stream": stream,
#    1013                 "style": style,
#    1014                 "user": user,
#    1015             },
#    1016             image_generate_params.ImageGenerateParamsStreaming
#    1017             if stream
#    1018             else image_generate_params.ImageGenerateParamsNonStreaming,
#    1019         ),
#    1020         options=make_request_options(
#    1021             extra_headers=extra_headers,
#    1022             extra_query=extra_query,
#    1023             extra_body=extra_body,
#    1024             timeout=timeout,
#    1025             security={"bearer_auth": True},
#    1026         ),
#    1027         cast_to=ImagesResponse,
#    1028         stream=stream or False,
#    1029         stream_cls=Stream[ImageGenStreamEvent],
#    1030     )
#
# File ~/Sites/ai-learning/llm_engineering/.venv/lib/python3.13/site-packages/openai/_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Sites/ai-learning/llm_engineering/.venv/lib/python3.13/site-packages/openai/_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "The model 'dall-e-3' does not exist.", 'type': 'image_generation_user_error', 'param': 'model', 'code': 'invalid_value'}}

# %% [markdown]
# ## Audio

# %%
def talker(message):
    response = openai.audio.speech.create(
        model="tts-1",
        voice="onyx",
        input=message)

    audio_stream = BytesIO(response.content)
    output_filename = "output_audio.mp3"
    with open(output_filename, "wb") as f:
        f.write(audio_stream.read())

    # Play the generated audio
    display(Audio(output_filename, autoplay=True))

talker("Well, hi there")
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Chat

# %%
def chat(history):
    messages = [{"role": "system", "content": system_message}] + history
    response = openai.chat.completions.create(model=MODEL, messages=messages, tools=tools)
    image = None
    
    if response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        response, animal1, animal2 = handle_tool_call(message)
        messages.append(message)
        messages.append(response)
        image = artist(animal1, animal2)
        response = openai.chat.completions.create(model=MODEL, messages=messages)
        
    reply = response.choices[0].message.content
    history += [{"role":"assistant", "content":reply}]

    # Comment out or delete the next line if you'd rather skip Audio for now..
    talker(reply)
    
    return history, image

# %%
def handle_tool_call(message):
    tool_call = message.tool_calls[0]
    arguments = json.loads(tool_call.function.arguments)
    animal1 = arguments.get('animal1')
    animal2 = arguments.get('animal2')
    animal_name = get_animal_name(animal1, animal2)
    response = {
        "role": "tool",
        "content": json.dumps({"animal1": animal1, "animal2": animal2, "animal_name": animal_name}),
        "tool_call_id": tool_call.id
    }
    return response, animal1, animal2

# %% [markdown]
# ## Gradio UI

# %%
with gr.Blocks() as ui:
    with gr.Row():
        chatbot = gr.Chatbot(height=500)
        image_output = gr.Image(height=500)
    with gr.Row():
        entry = gr.Textbox(label="Chat with our AI Assistant:")
    with gr.Row():
        clear = gr.Button("Clear")

    def do_entry(message, history):
        history += [{"role":"user", "content":message}]
        return "", history

    entry.submit(do_entry, inputs=[entry, chatbot], outputs=[entry, chatbot]).then(
        chat, inputs=chatbot, outputs=[chatbot, image_output]
    )
    clear.click(lambda: None, inputs=None, outputs=chatbot, queue=False)

ui.launch(inbrowser=True)
